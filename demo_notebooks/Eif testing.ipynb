# %%
import sys
sys.path.append('..')
import neurodynlib as nd
from brian2.units import *
import brian2 as b2
from brian2tools import brian_plot
import matplotlib.pyplot as plt

# %%
#x = nd.EifNeuron()
x = nd.AdexNeuron()
x.get_neuron_equations()
# Out:
# dvm/dt = (DeltaT*g_leak*exp((-V_threshold + vm)/DeltaT) + g_leak*(E_leak - vm) - w)/C : volt (unless refractory)
# dw/dt = (a*(-E_leak + vm) - w)/tau_w : amp

# %%
inputcurr = nd.input_factory.get_step_current(t_start=300, t_end=800, unit_time=ms, amplitude=0.2 * namp)
statemon, spikemon = x.simulate_neuron(I_stim=inputcurr)

# %%
brian_plot(statemon)

# %%
x.getting_started()
# Out:
# nr of spikes: 22
# nr of spikes: 22

# %%
x._min_curr_expl()

# %%
a = {}

# %%
a.update({'b': 1})

# %%
a
