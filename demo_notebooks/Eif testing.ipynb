# %%
import sys
sys.path.append('..')
import neurodynlib as nd
from brian2.units import *
import brian2 as b2
from brian2tools import brian_plot
import matplotlib.pyplot as plt

# %%
x = nd.EifNeuron()
x.get_neuron_equations()
# Out:
# dvm/dt = (DeltaT*g_leak*exp((-V_threshold + vm)/DeltaT) + g_leak*(E_leak - vm))/C : volt (unless refractory)

# %%
inputcurr = nd.input_factory.get_step_current(t_start=300, t_end=800, unit_time=ms, amplitude=0.2 * namp)
statemon, spikemon = x.simulate_neuron(I_stim=inputcurr)

# %%
brian_plot(statemon)

# %%
x.getting_started()
# Out:
# nr of spikes: 23
# nr of spikes: 23

# %%
x.getting_started_eif()
# Out:
# WARNING    Model equations use the "unless refractory" flag but no refractory keyword was given. [brian2.groups.neurongroup.no_refractory]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/brian2/core/network.py in before_run(self, run_namespace)
#     840                 try:
# --> 841                     obj.before_run(run_namespace)
#     842                 except Exception as ex:
#
# ~/anaconda3/lib/python3.7/site-packages/brian2/groups/neurongroup.py in before_run(self, run_namespace)
#     879         # Check units
# --> 880         self.equations.check_units(self, run_namespace=run_namespace)
#     881         # Check that subexpressions that refer to stateful functions are labeled
#
# ~/anaconda3/lib/python3.7/site-packages/brian2/equations/equations.py in check_units(self, group, run_namespace)
#     944         resolved_namespace = group.resolve_all(external, run_namespace,
# --> 945                                                user_identifiers=external)  # all variables are user defined
#     946
#
# ~/anaconda3/lib/python3.7/site-packages/brian2/groups/group.py in resolve_all(self, identifiers, run_namespace, user_identifiers, additional_variables)
#     738                                                  additional_variables=additional_variables,
# --> 739                                                  run_namespace=run_namespace)
#     740         return resolved
#
# ~/anaconda3/lib/python3.7/site-packages/brian2/groups/group.py in _resolve(self, identifier, run_namespace, user_identifier, additional_variables)
#     695         # namespace
# --> 696         return self._resolve_external(identifier, run_namespace=run_namespace)
#     697
#
# ~/anaconda3/lib/python3.7/site-packages/brian2/groups/group.py in _resolve_external(self, identifier, run_namespace, user_identifier, internal_variable)
#     819                                  identifier)
# --> 820                 raise KeyError(error_msg)
#     821
#
# KeyError: 'The identifier "V_threshold" could not be resolved.'
#
# During handling of the above exception, another exception occurred:
#
# BrianObjectException                      Traceback (most recent call last)
# <ipython-input-6-b88705c1b4e7> in <module>
# ----> 1 x.getting_started_eif()
#
# ~/PycharmProjects/neurodynlib/neurodynlib/neuron_models.py in getting_started_eif(self)
#     541         input_current = input_factory.get_step_current(t_start=20, t_end=120, unit_time=ms, amplitude=0.8 * namp)
#     542         state_monitor, spike_monitor = self.simulate_exponential_IF_neuron(
# --> 543             I_stim=input_current, simulation_time=180 * ms)
#     544         plot_tools.plot_voltage_and_current_traces(
#     545             state_monitor, input_current, title="step current", firing_threshold=EifNeuron.FIRING_THRESHOLD_v_spike)
#
# ~/PycharmProjects/neurodynlib/neurodynlib/neuron_models.py in simulate_exponential_IF_neuron(self, tau, R, E_leak, v_reset, VT, v_spike, delta_T, I_stim, simulation_time)
#     529         # run the simulation
#     530         net = b2.Network(neuron, voltage_monitor, spike_monitor)
# --> 531         net.run(simulation_time)
#     532
#     533         return voltage_monitor, spike_monitor
#
# ~/anaconda3/lib/python3.7/site-packages/brian2/core/base.py in device_override_decorated_function(*args, **kwds)
#     274                 return getattr(curdev, name)(*args, **kwds)
#     275             else:
# --> 276                 return func(*args, **kwds)
#     277
#     278         device_override_decorated_function.__doc__ = func.__doc__
#
# ~/anaconda3/lib/python3.7/site-packages/brian2/units/fundamentalunits.py in new_f(*args, **kwds)
#    2373                                                      get_dimensions(newkeyset[k]))
#    2374
# -> 2375             result = f(*args, **kwds)
#    2376             if 'result' in au:
#    2377                 if au['result'] == bool:
#
# ~/anaconda3/lib/python3.7/site-packages/brian2/core/network.py in run(self, duration, report, report_period, namespace, profile, level)
#     949             namespace = get_local_namespace(level=level+3)
#     950
# --> 951         self.before_run(namespace)
#     952
#     953         if len(self.objects)==0:
#
# ~/anaconda3/lib/python3.7/site-packages/brian2/core/base.py in device_override_decorated_function(*args, **kwds)
#     274                 return getattr(curdev, name)(*args, **kwds)
#     275             else:
# --> 276                 return func(*args, **kwds)
#     277
#     278         device_override_decorated_function.__doc__ = func.__doc__
#
# ~/anaconda3/lib/python3.7/site-packages/brian2/core/network.py in before_run(self, run_namespace)
#     841                     obj.before_run(run_namespace)
#     842                 except Exception as ex:
# --> 843                     raise brian_object_exception("An error occurred when preparing an object.", obj, ex)
#     844
#     845         # Check that no object has been run as part of another network before
#
# BrianObjectException: Original error and traceback:
# Traceback (most recent call last):
#   File "/home/henhok/anaconda3/lib/python3.7/site-packages/brian2/core/network.py", line 841, in before_run
#     obj.before_run(run_namespace)
#   File "/home/henhok/anaconda3/lib/python3.7/site-packages/brian2/groups/neurongroup.py", line 880, in before_run
#     self.equations.check_units(self, run_namespace=run_namespace)
#   File "/home/henhok/anaconda3/lib/python3.7/site-packages/brian2/equations/equations.py", line 945, in check_units
#     user_identifiers=external)  # all variables are user defined
#   File "/home/henhok/anaconda3/lib/python3.7/site-packages/brian2/groups/group.py", line 739, in resolve_all
#     run_namespace=run_namespace)
#   File "/home/henhok/anaconda3/lib/python3.7/site-packages/brian2/groups/group.py", line 696, in _resolve
#     return self._resolve_external(identifier, run_namespace=run_namespace)
#   File "/home/henhok/anaconda3/lib/python3.7/site-packages/brian2/groups/group.py", line 820, in _resolve_external
#     raise KeyError(error_msg)
# KeyError: 'The identifier "V_threshold" could not be resolved.'
#
# Error encountered with object named "neurongroup_1".
# Object was created here (most recent call only, full details in debug log):
#   File "../neurodynlib/neuron_models.py", line 523, in simulate_exponential_IF_neuron
#     neuron = b2.NeuronGroup(1, model=eqs, reset="vm=v_reset", threshold="vm>v_spike", method="euler")
#
# An error occurred when preparing an object. KeyError: 'The identifier "V_threshold" could not be resolved.'
# (See above for original error message and traceback.)
