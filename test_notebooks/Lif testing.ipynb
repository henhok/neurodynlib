# %%
import sys
sys.path.append('..')
import neurodynlib as nd
from brian2.units import *
import brian2 as b2
from brian2tools import brian_plot
import matplotlib.pyplot as plt

# %%
x = nd.LifNeuron()
x.get_neuron_equations()
# Out:
# dvm/dt = g_leak*(E_leak - vm)/C : volt (unless refractory)

# %%
inputcurr = nd.input_factory.get_step_current(t_start=300, t_end=800, unit_time=ms, amplitude=0.2 * namp)
statemon, spikemon = x.simulate_neuron(I_stim=inputcurr, C=100*pF)

# %%
brian_plot(statemon)

# %%
x.getting_started()
# Out:
# nr of spikes: 0
# nr of spikes: 5

# %%
x.getting_started_lif()
